# %%
import networkx as nx

# Membuat graf
G = nx.DiGraph()

# Menambahkan edge dengan bobot sebagai data (bobot tidak diperlukan untuk Betweenness)
G.add_edges_from([('Hafizh Ihsan', 'Dimas Arya'), ('Dimas Arya', 'Adinda Shazma'),
                  ('Adinda Shazma', 'Hafiiz Anindra'), ('Hafiiz Anindra', 'Fernanda Maulana')])

# Menghitung metrik-metrik
betweenness_centrality = nx.betweenness_centrality(G)
closeness_centrality = nx.closeness_centrality(G)
eigenvector_centrality = nx.eigenvector_centrality(G, max_iter=1000)  # Menambahkan parameter max_iter

# Menampilkan hasil
print("Betweenness Centrality:", betweenness_centrality)
print("Closeness Centrality:", closeness_centrality)
print("Eigenvector Centrality:", eigenvector_centrality)
# Out:
# Betweenness Centrality: {'Hafizh Ihsan': 0.0, 'Dimas Arya': 0.25, 'Adinda Shazma': 0.3333333333333333, 'Hafiiz Anindra': 0.25, 'Fernanda Maulana': 0.0}
# Closeness Centrality: {'Hafizh Ihsan': 0.0, 'Dimas Arya': 0.25, 'Adinda Shazma': 0.3333333333333333, 'Hafiiz Anindra': 0.375, 'Fernanda Maulana': 0.4}
# Eigenvector Centrality: {'Hafizh Ihsan': 3.63361523133218e-11, 'Dimas Arya': 3.2811545538929544e-08, 'Adinda Shazma': 1.4798043374209541e-05, 'Hafiiz Anindra': 0.004444367591975394, 'Fernanda Maulana': 0.9999901236400908}

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Membuat graf
G = nx.DiGraph()

# Menambahkan edge dengan bobot sebagai data (bobot tidak diperlukan untuk Betweenness)
edges = [('Hafizh Ihsan', 'Dimas Arya'), ('Dimas Arya', 'Adinda Shazma'),
         ('Adinda Shazma', 'Hafiiz Anindra'), ('Hafiiz Anindra', 'Fernanda Maulana')]

G.add_edges_from(edges)

# Menetapkan degree untuk setiap node
degree_data = {'Hafizh Ihsan': {'degree': 49, 'in_degree': 46, 'out_degree': 3},
               'Dimas Arya': {'degree': 49, 'in_degree': 40, 'out_degree': 9},
               'Adinda Shazma': {'degree': 19, 'in_degree': 10, 'out_degree': 9},
               'Hafiiz Anindra': {'degree': 17, 'in_degree': 7, 'out_degree': 10},
               'Fernanda Maulana': {'degree': 10, 'in_degree': 8, 'out_degree': 2}}

# Menetapkan data degree ke graf
nx.set_node_attributes(G, degree_data)

# Menghitung metrik-metrik
betweenness_centrality = nx.betweenness_centrality(G)
closeness_centrality = nx.closeness_centrality(G)
eigenvector_centrality = nx.eigenvector_centrality(G, max_iter=1000)

# Menampilkan hasil
print("Degree Centrality:")
print(nx.get_node_attributes(G, 'degree'))
print("\nBetweenness Centrality:")
print(betweenness_centrality)
print("\nCloseness Centrality:")
print(closeness_centrality)
print("\nEigenvector Centrality:")
print(eigenvector_centrality)

# Visualisasi graf
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, font_weight='bold', node_size=700, node_color='skyblue', font_size=8, font_color='black', arrowsize=10)
plt.show()
# Out:
# Degree Centrality:
# {'Hafizh Ihsan': 49, 'Dimas Arya': 49, 'Adinda Shazma': 19, 'Hafiiz Anindra': 17, 'Fernanda Maulana': 10}
#
# Betweenness Centrality:
# {'Hafizh Ihsan': 0.0, 'Dimas Arya': 0.25, 'Adinda Shazma': 0.3333333333333333, 'Hafiiz Anindra': 0.25, 'Fernanda Maulana': 0.0}
#
# Closeness Centrality:
# {'Hafizh Ihsan': 0.0, 'Dimas Arya': 0.25, 'Adinda Shazma': 0.3333333333333333, 'Hafiiz Anindra': 0.375, 'Fernanda Maulana': 0.4}
#
# Eigenvector Centrality:
# {'Hafizh Ihsan': 3.63361523133218e-11, 'Dimas Arya': 3.2811545538929544e-08, 'Adinda Shazma': 1.4798043374209541e-05, 'Hafiiz Anindra': 0.004444367591975394, 'Fernanda Maulana': 0.9999901236400908}

# %%
import networkx as nx
import matplotlib.pyplot as plt
from networkx.algorithms import community

# Inisialisasi graf
G = nx.Graph()

# Tambahkan node
G.add_nodes_from(range(1, 51))

# Tambahkan edge timbal balik
G.add_edges_from([(1, 2), (2, 1), (3, 4), (4, 3), (5, 6), (6, 5), (7, 8), (8, 7), (9, 10), (10, 9)])

# Tambahkan edge untuk membentuk cluster
G.add_edges_from([(1, i) for i in range(2, 19)])
G.add_edges_from([(2, i) for i in range(1, 19)])
G.add_edges_from([(3, i) for i in range(4, 18)])
G.add_edges_from([(4, i) for i in range(3, 18)])
G.add_edges_from([(5, i) for i in range(6, 18)])
G.add_edges_from([(6, i) for i in range(5, 18)])
G.add_edges_from([(7, i) for i in range(8, 18)])
G.add_edges_from([(8, i) for i in range(7, 18)])

# Temukan komponen terhubung
connected_components = list(nx.connected_components(G))

# Ambil subgraf terbesar
largest_component = max(connected_components, key=len)
G = G.subgraph(largest_component)

# Menghitung level sistem Diameter, Density, Reciprocity
diameter = nx.diameter(G)
density = nx.density(G)
reciprocity = nx.reciprocity(G)

# Menghitung modularity
partition = community.greedy_modularity_communities(G)
modularity = community.modularity(G, partition)

# Menampilkan hasil
print(f"Level sistem Diameter: {diameter}")
print(f"Level sistem Density: {density}")
print(f"Level sistem Reciprocity: {reciprocity}")
print(f"Level sistem Modularity: {modularity}")

# Menampilkan graf
nx.draw(G, with_labels=True)
plt.show()
# Out:
# Level sistem Diameter: 2
# Level sistem Density: 0.6993464052287581
# Level sistem Reciprocity: 0.0
# Level sistem Modularity: 0.025941130229714365

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Membuat graf jaringan sosial
G = nx.Graph()

# Menambahkan node dan edge
actors = ["Actor" + str(i) for i in range(1, 51)]
G.add_nodes_from(actors)

# Menghubungkan aktor untuk membentuk jaringan dengan 53 edge (termasuk timbal balik)
edges = [("Actor1", "Actor2"), ("Actor2", "Actor3"), ("Actor3", "Actor4"), ("Actor4", "Actor5"),
         ("Actor1", "Actor6"), ("Actor6", "Actor7"), ("Actor7", "Actor8"), ("Actor8", "Actor9"),
         ("Actor1", "Actor10"), ("Actor10", "Actor11"), ("Actor11", "Actor12"), ("Actor12", "Actor13"),
         ("Actor1", "Actor14"), ("Actor14", "Actor15"), ("Actor15", "Actor16"), ("Actor16", "Actor17"),
         ("Actor1", "Actor18"), ("Actor18", "Actor19"), ("Actor19", "Actor20"), ("Actor20", "Actor21"),
         ("Actor1", "Actor22"), ("Actor22", "Actor23"), ("Actor23", "Actor24"), ("Actor24", "Actor25"),
         ("Actor1", "Actor26"), ("Actor26", "Actor27"), ("Actor27", "Actor28"), ("Actor28", "Actor29"),
         ("Actor1", "Actor30"), ("Actor30", "Actor31"), ("Actor31", "Actor32"), ("Actor32", "Actor33"),
         ("Actor1", "Actor34"), ("Actor34", "Actor35"), ("Actor35", "Actor36"), ("Actor36", "Actor37"),
         ("Actor1", "Actor38"), ("Actor38", "Actor39"), ("Actor39", "Actor40"), ("Actor40", "Actor41"),
         ("Actor1", "Actor42"), ("Actor42", "Actor43"), ("Actor43", "Actor44"), ("Actor44", "Actor45"),
         ("Actor1", "Actor46"), ("Actor46", "Actor47"), ("Actor47", "Actor48"), ("Actor48", "Actor49"),
         ("Actor1", "Actor50")]

G.add_edges_from(edges)

# Menghitung metrik-metrik level sistem
diameter = nx.diameter(G)
density = nx.density(G)
reciprocity = nx.reciprocity(G)
modularity = nx.algorithms.community.modularity(G, [set(G.nodes)])

print("System Level Metrics:")
print(f"Diameter: {diameter}")
print(f"Density: {density}")
print(f"Reciprocity: {reciprocity}")
print(f"Modularity: {modularity}")
print("\n")

# Membuat 3 cluster dengan informasi yang dijelaskan
clusters = {
    "Cluster1": {"main_actor": "Actor1", "target_actors": ["Actor" + str(i) for i in range(2, 28)]},
    "Cluster2": {"main_actor": "Actor1", "target_actors": ["Actor" + str(i) for i in range(28, 45)]},
    "Cluster3": {"main_actor": "Actor1", "target_actors": ["Actor" + str(i) for i in range(45, 51)]}
}

# Menghitung metrik-metrik pada level cluster
for cluster_name, cluster_info in clusters.items():
    main_actor = cluster_info["main_actor"]
    target_actors = cluster_info["target_actors"]

    # Memastikan bahwa subgraf dalam cluster terhubung
    connected_actors = [main_actor] + target_actors
    cluster_graph = G.subgraph(connected_actors)

    if not nx.is_connected(cluster_graph):
        print(f"Warning: {cluster_name} is not connected.")
    else:
        cluster_diameter = nx.diameter(cluster_graph)
        cluster_density = nx.density(cluster_graph)

        print(f"{cluster_name} Metrics:")
        print(f"  Diameter: {cluster_diameter}")
        print(f"  Density: {cluster_density}")
        print("\n")

# Menghitung panjang jarak node terdekat dan terjauh
shortest_path_lengths = nx.shortest_path_length(G)
max_eccentricity = max(nx.eccentricity(G).values())

print(f"Panjang Jarak Node Terdekat: 1")
print(f"Panjang Jarak Node Terjauh: {max_eccentricity}")
# Out:
# System Level Metrics:
# Diameter: 8
# Density: 0.04
# Reciprocity: 0.0
# Modularity: 0.0
#
#
# Cluster1 Metrics:
#   Diameter: 8
#   Density: 0.07407407407407407
#
#
# Warning: Cluster2 is not connected.
# Warning: Cluster3 is not connected.
# Panjang Jarak Node Terdekat: 1
# Panjang Jarak Node Terjauh: 8

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Membuat graf jaringan sosial
G = nx.Graph()

# Menambahkan node dan edge
actors = ["Actor" + str(i) for i in range(1, 51)]
G.add_nodes_from(actors)

# Menghubungkan aktor untuk membentuk jaringan dengan 56 edge (termasuk timbal balik)
edges = [("Actor1", "Actor2"), ("Actor2", "Actor3"), ("Actor3", "Actor4"), ("Actor4", "Actor5"),
         ("Actor1", "Actor6"), ("Actor6", "Actor7"), ("Actor7", "Actor8"), ("Actor8", "Actor9"),
         ("Actor1", "Actor10"), ("Actor10", "Actor11"), ("Actor11", "Actor12"), ("Actor12", "Actor13"),
         ("Actor1", "Actor14"), ("Actor14", "Actor15"), ("Actor15", "Actor16"), ("Actor16", "Actor17"),
         ("Actor1", "Actor18"), ("Actor18", "Actor19"), ("Actor19", "Actor20"), ("Actor20", "Actor21"),
         ("Actor1", "Actor22"), ("Actor22", "Actor23"), ("Actor23", "Actor24"), ("Actor24", "Actor25"),
         ("Actor1", "Actor26"), ("Actor26", "Actor27"), ("Actor27", "Actor28"), ("Actor28", "Actor29"),
         ("Actor1", "Actor30"), ("Actor30", "Actor31"), ("Actor31", "Actor32"), ("Actor32", "Actor33"),
         ("Actor1", "Actor34"), ("Actor34", "Actor35"), ("Actor35", "Actor36"), ("Actor36", "Actor37"),
         ("Actor1", "Actor38"), ("Actor38", "Actor39"), ("Actor39", "Actor40"), ("Actor40", "Actor41"),
         ("Actor1", "Actor42"), ("Actor42", "Actor43"), ("Actor43", "Actor44"), ("Actor44", "Actor45"),
         ("Actor1", "Actor46"), ("Actor46", "Actor47"), ("Actor47", "Actor48"), ("Actor48", "Actor49"),
         ("Actor1", "Actor50")]

G.add_edges_from(edges)

# Menghitung metrik-metrik level sistem
diameter = nx.diameter(G)
density = nx.density(G)
reciprocity = nx.reciprocity(G)
modularity = nx.algorithms.community.modularity(G, [set(G.nodes)])

print("System Level Metrics:")
print(f"Diameter: {diameter}")
print(f"Density: {density}")
print(f"Reciprocity: {reciprocity}")
print(f"Modularity: {modularity}")
print("\n")

# Membuat 4 cluster dengan informasi yang dijelaskan
clusters = {
    "Cluster1": {"main_actor": "Actor1", "target_actors": ["Actor" + str(i) for i in range(2, 19)]},
    "Cluster2": {"main_actor": "Actor1", "target_actors": ["Actor" + str(i) for i in range(19, 36)]},
    "Cluster3": {"main_actor": "Actor1", "target_actors": ["Actor" + str(i) for i in range(36, 51)]},
    "Cluster4": {"main_actor": "Actor1", "target_actors": ["Actor" + str(i) for i in range(51, 67)]}
}

# Menghitung metrik-metrik pada level cluster
for cluster_name, cluster_info in clusters.items():
    main_actor = cluster_info["main_actor"]
    target_actors = cluster_info["target_actors"]

    # Memastikan bahwa subgraf dalam cluster terhubung
    connected_actors = [main_actor] + target_actors
    cluster_graph = G.subgraph(connected_actors)

    if not nx.is_connected(cluster_graph):
        print(f"Warning: {cluster_name} is not connected.")
    else:
        cluster_diameter = nx.diameter(cluster_graph)
        cluster_density = nx.density(cluster_graph)

        print(f"{cluster_name} Metrics:")
        print(f"  Diameter: {cluster_diameter}")
        print(f"  Density: {cluster_density}")
        print("\n")

# Menghitung panjang jarak node terdekat dan terjauh
source_node = list(G.nodes)[0]  # Mengambil node pertama dari graf
shortest_path_lengths = nx.single_source_shortest_path_length(G, source=source_node)
max_eccentricity = max(nx.eccentricity(G).values())

print(f"Panjang Jarak Node Terdekat: {min(shortest_path_lengths.values())}")
print(f"Panjang Jarak Node Terjauh: {max_eccentricity}")
# Out:
# System Level Metrics:
# Diameter: 8
# Density: 0.04
# Reciprocity: 0.0
# Modularity: 0.0
#
#
# Cluster1 Metrics:
#   Diameter: 8
#   Density: 0.1111111111111111
#
#
# Warning: Cluster2 is not connected.
# Warning: Cluster3 is not connected.
# Cluster4 Metrics:
#   Diameter: 0
#   Density: 0
#
#
# Panjang Jarak Node Terdekat: 0
# Panjang Jarak Node Terjauh: 8

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Membuat graf jaringan sosial
G = nx.Graph()

# Menambahkan node dan edge
actors = ["Actor" + str(i) for i in range(1, 51)]
G.add_nodes_from(actors)

# Menghubungkan aktor untuk membentuk jaringan dengan 56 edge (termasuk timbal balik)
edges = [("Actor1", "Actor2"), ("Actor2", "Actor3"), ("Actor3", "Actor4"), ("Actor4", "Actor5"),
         ("Actor1", "Actor6"), ("Actor6", "Actor7"), ("Actor7", "Actor8"), ("Actor8", "Actor9"),
         ("Actor1", "Actor10"), ("Actor10", "Actor11"), ("Actor11", "Actor12"), ("Actor12", "Actor13"),
         ("Actor1", "Actor14"), ("Actor14", "Actor15"), ("Actor15", "Actor16"), ("Actor16", "Actor17"),
         ("Actor1", "Actor18"), ("Actor18", "Actor19"), ("Actor19", "Actor20"), ("Actor20", "Actor21"),
         ("Actor1", "Actor22"), ("Actor22", "Actor23"), ("Actor23", "Actor24"), ("Actor24", "Actor25"),
         ("Actor1", "Actor26"), ("Actor26", "Actor27"), ("Actor27", "Actor28"), ("Actor28", "Actor29"),
         ("Actor1", "Actor30"), ("Actor30", "Actor31"), ("Actor31", "Actor32"), ("Actor32", "Actor33"),
         ("Actor1", "Actor34"), ("Actor34", "Actor35"), ("Actor35", "Actor36"), ("Actor36", "Actor37"),
         ("Actor1", "Actor38"), ("Actor38", "Actor39"), ("Actor39", "Actor40"), ("Actor40", "Actor41"),
         ("Actor1", "Actor42"), ("Actor42", "Actor43"), ("Actor43", "Actor44"), ("Actor44", "Actor45"),
         ("Actor1", "Actor46"), ("Actor46", "Actor47"), ("Actor47", "Actor48"), ("Actor48", "Actor49"),
         ("Actor1", "Actor50")]

G.add_edges_from(edges)

# Membuat 4 cluster dengan informasi yang dijelaskan
clusters = {
    "Cluster1": {"main_actor": "Actor1", "target_actors": ["Actor" + str(i) for i in range(2, 19)]},
    "Cluster2": {"main_actor": "Actor2", "target_actors": ["Actor" + str(i) for i in range(19, 36)]},
    "Cluster3": {"main_actor": "Actor3", "target_actors": ["Actor" + str(i) for i in range(36, 51)]},
    "Cluster4": {"main_actor": "Actor4", "target_actors": ["Actor" + str(i) for i in range(51, 67)]}
}

# Menghitung metrik-metrik pada level cluster
for cluster_name, cluster_info in clusters.items():
    main_actor = cluster_info["main_actor"]
    target_actors = cluster_info["target_actors"]

    # Memastikan bahwa subgraf dalam cluster terhubung
    connected_actors = [main_actor] + target_actors
    cluster_graph = G.subgraph(connected_actors)

    if not nx.is_connected(cluster_graph):
        print(f"Warning: {cluster_name} is not connected.")
    else:
        cluster_diameter = nx.diameter(cluster_graph)
        cluster_density = nx.density(cluster_graph)

        print(f"{cluster_name} Metrics:")
        print(f"  Diameter: {cluster_diameter}")
        print(f"  Density: {cluster_density}")
        print("\n")

# Menghitung panjang jarak node terdekat dan terjauh
shortest_path_lengths = nx.single_source_shortest_path_length(G, source="Actor1")
max_eccentricity = max(nx.eccentricity(G).values())

print(f"Panjang Jarak Node Terdekat: {min(shortest_path_lengths.values())}")
print(f"Panjang Jarak Node Terjauh: {max_eccentricity}")
# Out:
# Cluster1 Metrics:
#   Diameter: 8
#   Density: 0.1111111111111111
#
#
# Warning: Cluster2 is not connected.
# Warning: Cluster3 is not connected.
# Cluster4 Metrics:
#   Diameter: 0
#   Density: 0
#
#
# Panjang Jarak Node Terdekat: 0
# Panjang Jarak Node Terjauh: 8

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Membuat graf jaringan sosial
G = nx.Graph()

# Menambahkan node dan edge
actors = ["Actor" + str(i) for i in range(1, 51)]
G.add_nodes_from(actors)

# Menghubungkan aktor untuk membentuk jaringan dengan 56 edge (termasuk timbal balik)
edges = [("Actor1", "Actor2"), ("Actor2", "Actor3"), ("Actor3", "Actor4"), ("Actor4", "Actor5"),
         ("Actor1", "Actor6"), ("Actor6", "Actor7"), ("Actor7", "Actor8"), ("Actor8", "Actor9"),
         ("Actor1", "Actor10"), ("Actor10", "Actor11"), ("Actor11", "Actor12"), ("Actor12", "Actor13"),
         ("Actor1", "Actor14"), ("Actor14", "Actor15"), ("Actor15", "Actor16"), ("Actor16", "Actor17"),
         ("Actor1", "Actor18"), ("Actor18", "Actor19"), ("Actor19", "Actor20"), ("Actor20", "Actor21"),
         ("Actor1", "Actor22"), ("Actor22", "Actor23"), ("Actor23", "Actor24"), ("Actor24", "Actor25"),
         ("Actor1", "Actor26"), ("Actor26", "Actor27"), ("Actor27", "Actor28"), ("Actor28", "Actor29"),
         ("Actor1", "Actor30"), ("Actor30", "Actor31"), ("Actor31", "Actor32"), ("Actor32", "Actor33"),
         ("Actor1", "Actor34"), ("Actor34", "Actor35"), ("Actor35", "Actor36"), ("Actor36", "Actor37"),
         ("Actor1", "Actor38"), ("Actor38", "Actor39"), ("Actor39", "Actor40"), ("Actor40", "Actor41"),
         ("Actor1", "Actor42"), ("Actor42", "Actor43"), ("Actor43", "Actor44"), ("Actor44", "Actor45"),
         ("Actor1", "Actor46"), ("Actor46", "Actor47"), ("Actor47", "Actor48"), ("Actor48", "Actor49"),
         ("Actor1", "Actor50")]

G.add_edges_from(edges)

# Menghitung metrik-metrik level sistem
diameter = nx.diameter(G)
density = nx.density(G)
reciprocity = nx.reciprocity(G)
modularity = nx.algorithms.community.modularity(G, [set(G.nodes)])

print("System Level Metrics:")
print(f"Diameter: {diameter}")
print(f"Density: {density}")
print(f"Reciprocity: {reciprocity}")
print(f"Modularity: {modularity}")
print("\n")

# Membuat 4 cluster dengan informasi yang dijelaskan
clusters = {
    "Cluster1": {"main_actor": "Actor1", "target_actors": ["Actor" + str(i) for i in range(2, 19)]},
    "Cluster2": {"main_actor": "Actor1", "target_actors": ["Actor" + str(i) for i in range(19, 36)]},
    "Cluster3": {"main_actor": "Actor1", "target_actors": ["Actor" + str(i) for i in range(36, 51)]},
    "Cluster4": {"main_actor": "Actor1", "target_actors": ["Actor" + str(i) for i in range(51, 67)]}
}

# Menghitung metrik-metrik pada level cluster
for cluster_name, cluster_info in clusters.items():
    main_actor = cluster_info["main_actor"]
    target_actors = cluster_info["target_actors"]

    # Memastikan bahwa subgraf dalam cluster terhubung
    connected_actors = [main_actor] + target_actors
    cluster_graph = G.subgraph(connected_actors)

    if not nx.is_connected(cluster_graph):
        print(f"Warning: {cluster_name} is not connected.")
    else:
        cluster_diameter = nx.diameter(cluster_graph)
        cluster_density = nx.density(cluster_graph)
        shortest_path_lengths = nx.single_source_shortest_path_length(cluster_graph, source=main_actor)
        max_eccentricity = max(nx.eccentricity(cluster_graph).values())

        print(f"{cluster_name} Metrics:")
        print(f"  Diameter: {cluster_diameter}")
        print(f"  Density: {cluster_density}")
        print(f"  Panjang Jarak Node Terdekat: {min(shortest_path_lengths.values())}")
        print(f"  Panjang Jarak Node Terjauh: {max_eccentricity}")
        print("\n")
# Out:
# System Level Metrics:
# Diameter: 8
# Density: 0.04
# Reciprocity: 0.0
# Modularity: 0.0
#
#
# Cluster1 Metrics:
#   Diameter: 8
#   Density: 0.1111111111111111
#   Panjang Jarak Node Terdekat: 0
#   Panjang Jarak Node Terjauh: 8
#
#
# Warning: Cluster2 is not connected.
# Warning: Cluster3 is not connected.
# Cluster4 Metrics:
#   Diameter: 0
#   Density: 0
#   Panjang Jarak Node Terdekat: 0
#   Panjang Jarak Node Terjauh: 0

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Membuat graf jaringan sosial
G = nx.Graph()

# Menambahkan node dan edge
actors = ["Actor" + str(i) for i in range(1, 51)]
G.add_nodes_from(actors)

# Menghubungkan aktor untuk membentuk jaringan dengan 56 edge (termasuk timbal balik)
edges = [("Actor1", "Actor2"), ("Actor2", "Actor3"), ("Actor3", "Actor4"), ("Actor4", "Actor5"),
         ("Actor1", "Actor6"), ("Actor6", "Actor7"), ("Actor7", "Actor8"), ("Actor8", "Actor9"),
         ("Actor1", "Actor10"), ("Actor10", "Actor11"), ("Actor11", "Actor12"), ("Actor12", "Actor13"),
         ("Actor1", "Actor14"), ("Actor14", "Actor15"), ("Actor15", "Actor16"), ("Actor16", "Actor17"),
         ("Actor1", "Actor18"), ("Actor18", "Actor19"), ("Actor19", "Actor20"), ("Actor20", "Actor21"),
         ("Actor1", "Actor22"), ("Actor22", "Actor23"), ("Actor23", "Actor24"), ("Actor24", "Actor25"),
         ("Actor1", "Actor26"), ("Actor26", "Actor27"), ("Actor27", "Actor28"), ("Actor28", "Actor29"),
         ("Actor1", "Actor30"), ("Actor30", "Actor31"), ("Actor31", "Actor32"), ("Actor32", "Actor33"),
         ("Actor1", "Actor34"), ("Actor34", "Actor35"), ("Actor35", "Actor36"), ("Actor36", "Actor37"),
         ("Actor1", "Actor38"), ("Actor38", "Actor39"), ("Actor39", "Actor40"), ("Actor40", "Actor41"),
         ("Actor1", "Actor42"), ("Actor42", "Actor43"), ("Actor43", "Actor44"), ("Actor44", "Actor45"),
         ("Actor1", "Actor46"), ("Actor46", "Actor47"), ("Actor47", "Actor48"), ("Actor48", "Actor49"),
         ("Actor1", "Actor50")]

G.add_edges_from(edges)

# Menghitung metrik-metrik level sistem
diameter = nx.diameter(G)
density = nx.density(G)
reciprocity = nx.reciprocity(G)
modularity = nx.algorithms.community.modularity(G, [set(G.nodes)])

print("System Level Metrics:")
print(f"Diameter: {diameter}")
print(f"Density: {density}")
print(f"Reciprocity: {reciprocity}")
print(f"Modularity: {modularity}")
print("\n")

# Membuat 4 cluster dengan informasi yang dijelaskan
clusters = {
    "Cluster1": {"main_actor": "Actor1", "target_actors": ["Actor" + str(i) for i in range(2, 19)]},
    "Cluster2": {"main_actor": "Actor1", "target_actors": ["Actor" + str(i) for i in range(19, 36)]},
    "Cluster3": {"main_actor": "Actor1", "target_actors": ["Actor" + str(i) for i in range(36, 51)]},
    "Cluster4": {"main_actor": "Actor1", "target_actors": ["Actor" + str(i) for i in range(51, 67)]}
}

# Menghitung metrik-metrik pada level cluster
for cluster_name, cluster_info in clusters.items():
    main_actor = cluster_info["main_actor"]
    target_actors = cluster_info["target_actors"]

    # Memastikan bahwa subgraf dalam cluster terhubung
    connected_actors = [main_actor] + target_actors
    cluster_graph = G.subgraph(connected_actors)

    if not nx.is_connected(cluster_graph):
        print(f"Warning: {cluster_name} is not connected.")
    else:
        cluster_diameter = nx.diameter(cluster_graph)
        cluster_density = nx.density(cluster_graph)

        # Penanganan kasus graf kosong
        if len(cluster_graph.edges) > 0:
            cluster_reciprocity = nx.reciprocity(cluster_graph)

            # Penanganan kasus pembagian nol
            deg_sum = sum(dict(cluster_graph.degree(weight='weight')).values())
            if deg_sum > 0:
                norm = 1 / deg_sum**2
                cluster_modularity = nx.algorithms.community.modularity(cluster_graph, [set(cluster_graph.nodes)])
            else:
                cluster_modularity = None
        else:
            cluster_reciprocity = None
            cluster_modularity = None

        print(f"{cluster_name} Metrics:")
        print(f"  Diameter: {cluster_diameter}")
        print(f"  Density: {cluster_density}")
        print(f"  Reciprocity: {cluster_reciprocity}")
        print(f"  Modularity: {cluster_modularity}")
        print("\n")

# Menghitung panjang jarak node terdekat dan terjauh
source_node = list(G.nodes)[0]  # Mengambil node pertama dari graf
shortest_path_lengths = nx.single_source_shortest_path_length(G, source=source_node)
max_eccentricity = max(nx.eccentricity(G).values())

print(f"Panjang Jarak Node Terdekat: {min(shortest_path_lengths.values())}")
print(f"Panjang Jarak Node Terjauh: {max_eccentricity}")
# Out:
# System Level Metrics:
# Diameter: 8
# Density: 0.04
# Reciprocity: 0.0
# Modularity: 0.0
#
#
# Cluster1 Metrics:
#   Diameter: 8
#   Density: 0.1111111111111111
#   Reciprocity: 0.0
#   Modularity: 0.0
#
#
# Warning: Cluster2 is not connected.
# Warning: Cluster3 is not connected.
# Cluster4 Metrics:
#   Diameter: 0
#   Density: 0
#   Reciprocity: None
#   Modularity: None
#
#
# Panjang Jarak Node Terdekat: 0
# Panjang Jarak Node Terjauh: 8

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Membuat graf jaringan sosial
G = nx.Graph()

# Menambahkan node dan edge
actors = ["Actor" + str(i) for i in range(1, 51)]
G.add_nodes_from(actors)

# Menghubungkan aktor untuk membentuk jaringan dengan 53 edge (termasuk timbal balik)
edges = [("Actor1", "Actor2"), ("Actor2", "Actor3"), ("Actor3", "Actor4"), ("Actor4", "Actor5"),
         ("Actor1", "Actor6"), ("Actor6", "Actor7"), ("Actor7", "Actor8"), ("Actor8", "Actor9"),
         ("Actor1", "Actor10"), ("Actor10", "Actor11"), ("Actor11", "Actor12"), ("Actor12", "Actor13"),
         ("Actor1", "Actor14"), ("Actor14", "Actor15"), ("Actor15", "Actor16"), ("Actor16", "Actor17"),
         ("Actor1", "Actor18"), ("Actor18", "Actor19"), ("Actor19", "Actor20"), ("Actor20", "Actor21"),
         ("Actor1", "Actor22"), ("Actor22", "Actor23"), ("Actor23", "Actor24"), ("Actor24", "Actor25"),
         ("Actor1", "Actor26"), ("Actor26", "Actor27"), ("Actor27", "Actor28"), ("Actor28", "Actor29"),
         ("Actor1", "Actor30"), ("Actor30", "Actor31"), ("Actor31", "Actor32"), ("Actor32", "Actor33"),
         ("Actor1", "Actor34"), ("Actor34", "Actor35"), ("Actor35", "Actor36"), ("Actor36", "Actor37"),
         ("Actor1", "Actor38"), ("Actor38", "Actor39"), ("Actor39", "Actor40"), ("Actor40", "Actor41"),
         ("Actor1", "Actor42"), ("Actor42", "Actor43"), ("Actor43", "Actor44"), ("Actor44", "Actor45"),
         ("Actor1", "Actor46"), ("Actor46", "Actor47"), ("Actor47", "Actor48"), ("Actor48", "Actor49"),
         ("Actor1", "Actor50")]

G.add_edges_from(edges)

# Menghitung metrik-metrik level sistem
diameter = nx.diameter(G)
density = nx.density(G)
reciprocity = nx.reciprocity(G)
modularity = nx.algorithms.community.modularity(G, [set(G.nodes)])

print("System Level Metrics:")
print(f"Diameter: {diameter}")
print(f"Density: {density}")
print(f"Reciprocity: {reciprocity}")
print(f"Modularity: {modularity}")
print("\n")

# Membuat 3 cluster dengan informasi yang dijelaskan
clusters = {
    "Cluster1": {"main_actor": "Actor1", "target_actors": ["Actor" + str(i) for i in range(2, 28)]},
    "Cluster2": {"main_actor": "Actor1", "target_actors": ["Actor" + str(i) for i in range(28, 45)]},
    "Cluster3": {"main_actor": "Actor1", "target_actors": ["Actor" + str(i) for i in range(45, 51)]}
}

# Menghitung metrik-metrik pada level cluster
for cluster_name, cluster_info in clusters.items():
    main_actor = cluster_info["main_actor"]
    target_actors = cluster_info["target_actors"]

    # Memastikan bahwa subgraf dalam cluster terhubung
    connected_actors = [main_actor] + target_actors
    cluster_graph = G.subgraph(connected_actors)

    if not nx.is_connected(cluster_graph):
        print(f"Warning: {cluster_name} is not connected.")
    else:
        cluster_diameter = nx.diameter(cluster_graph)
        cluster_density = nx.density(cluster_graph)
        cluster_reciprocity = nx.reciprocity(cluster_graph)
        cluster_modularity = nx.algorithms.community.modularity(cluster_graph, [set(cluster_graph.nodes)])

        print(f"{cluster_name} Metrics:")
        print(f"  Diameter: {cluster_diameter}")
        print(f"  Density: {cluster_density}")
        print(f"  Reciprocity: {cluster_reciprocity}")
        print(f"  Modularity: {cluster_modularity}")
        print("\n")

# Menghitung panjang jarak node terdekat dan terjauh
source_node = list(G.nodes)[0]  # Mengambil node pertama dari graf
shortest_path_lengths = nx.single_source_shortest_path_length(G, source=source_node)
max_eccentricity = max(nx.eccentricity(G).values())

print(f"Panjang Jarak Node Terdekat: {min(shortest_path_lengths.values())}")
print(f"Panjang Jarak Node Terjauh: {max_eccentricity}")
# Out:
# System Level Metrics:
# Diameter: 8
# Density: 0.04
# Reciprocity: 0.0
# Modularity: 0.0
#
#
# Cluster1 Metrics:
#   Diameter: 8
#   Density: 0.07407407407407407
#   Reciprocity: 0.0
#   Modularity: 0.0
#
#
# Warning: Cluster2 is not connected.
# Warning: Cluster3 is not connected.
# Panjang Jarak Node Terdekat: 0
# Panjang Jarak Node Terjauh: 8
